# %%
#This a numerical computation library to work with array's and metrices
import numpy as np

#This is a library to manipulate data and perform aggregate operations on data.
import pandas as pd

# This is a plotting library for pretty pictures.
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_gdrive = pd.read_csv("/content/drive/MyDrive/Data collection/oscardata.csv")

# %% [markdown]
# ## Data infrmation by the Basics of Pandas Dataframe

# %%
df_gdrive.head()
# Out:
#    Unnamed: 0                               Film  Year  Award  Nomination
# 0           0  Everything Everywhere All at Once  2022      7          11
# 1           1     All Quiet on the Western Front  2022      4           9
# 2           2                          The Whale  2022      2           3
# 3           3                  Top Gun: Maverick  2022      1           6
# 4           4     Black Panther: Wakanda Forever  2022      1           5

# %%
df_gdrive.shape
# Out:
# (1360, 5)

# %%
#descriptive stats of the dataframe
df_gdrive.describe()
# Out:
#         Unnamed: 0         Year        Award   Nomination
# count  1360.000000  1360.000000  1360.000000  1360.000000
# mean    679.500000  1883.550000     1.572059     3.611765
# std     392.742494   416.573338     1.388203     3.119996
# min       0.000000    21.000000     0.000000     0.000000
# 25%     339.750000  1950.000000     1.000000     1.000000
# 50%     679.500000  1973.500000     1.000000     2.000000
# 75%    1019.250000  1998.000000     2.000000     6.000000
# max    1359.000000  2022.000000    11.000000    14.000000

# %%
#setting setting index column
df_gdrive = df_gdrive.set_index("Film")
df_gdrive.head()
# Out:
#                                    Unnamed: 0  Year  Award  Nomination
# Film
# Everything Everywhere All at Once           0  2022      7          11
# All Quiet on the Western Front              1  2022      4           9
# The Whale                                   2  2022      2           3
# Top Gun: Maverick                           3  2022      1           6
# Black Panther: Wakanda Forever              4  2022      1           5

# %% [markdown]
# ## Plotting

# %%
df_gdrive['Year']  #cloumn from data sheet
# Out:
# Film
# Everything Everywhere All at Once    2022
# All Quiet on the Western Front       2022
# The Whale                            2022
# Top Gun: Maverick                    2022
# Black Panther: Wakanda Forever       2022
#                                      ...
# The Yankee Doodle Mouse              1943
# The Yearling                         1946
# Yesterday, Today and Tomorrow        1964
# You Can't Take It with You           1938
# Zorba the Greek                      1964
# Name: Year, Length: 1360, dtype: int64

# %%
df_gdrive['Award']
# Out:
# Film
# Everything Everywhere All at Once    7
# All Quiet on the Western Front       4
# The Whale                            2
# Top Gun: Maverick                    1
# Black Panther: Wakanda Forever       1
#                                     ..
# The Yankee Doodle Mouse              1
# The Yearling                         2
# Yesterday, Today and Tomorrow        1
# You Can't Take It with You           2
# Zorba the Greek                      3
# Name: Award, Length: 1360, dtype: int64

# %%
#plotting line graphs from Pandas columns
df_gdrive['Award'].plot(figsize=(10,6));
plt.title("Oscar Data")
# Out:
# Text(0.5, 1.0, 'Oscar Data')

# %%
df_gdrive['Year'].plot()
plt.title("Oscar Data")
# Out:
# Text(0.5, 1.0, 'Oscar Data')

# %%
df_gdrive['Nomination'].plot(figsize=(19,4));
plt.title("Oscar Data")
# Out:
# Text(0.5, 1.0, 'Oscar Data')

# %%
returns = df_gdrive['Year'].pct_change()
returns.plot();

# %%
#histogram of price returns
returns.plot(kind="hist", bins=15);

# %%
#box plot of price returns
returns.plot(kind="box");

# %% [markdown]
# For more details on usage and examples of Numpy, Pandas and Matplotlib view the official documentations.
#
# * Numpy : https://numpy.org/
# * Pandas : https://pandas.pydata.org/
# * Matplotlib : https://matplotlib.org/
